# %% [markdown]
# ![featurewiz_logo.jpg](attachment:featurewiz_logo.jpg)

# %% [markdown]
# Github Link: https://github.com/AutoViML/featurewiz

# %% [markdown]
# # Installing Featurewiz

# %%
# !pip install featurewiz

# %%
import numpy as np
import pandas as pd
import featurewiz
# Out:
# Imported featurewiz: advanced feature engg and selection library. Version=0.0.33
# output = featurewiz(dataname, target, corr_limit=0.70,
#                     verbose=2, sep=',', header=0, test_data='',
#                     feature_engg='', category_encoders='')
# Create new features via 'feature_engg' flag : ['interactions','groupby','target']

# %%
#importing dataset as dataframe to work with
df=pd.read_csv('papermil_data_new.csv')

# %%
df.head()
# Out:
#         a       b       c       d       e       f       g       h       i  \
# 0  185.99  3075.3  48.750  231.28  246.49  246.86  246.41  246.53  95.750
# 1  185.37  3056.2  40.707  228.65  244.26  243.49  243.84  244.05  95.750
# 2  185.55  3046.1  40.638  208.19  223.78  222.93  223.66  223.29  75.750
# 3  187.04  3083.1  40.638  209.97  225.40  224.40  225.11  224.71  79.125
# 4  205.80  3401.1  30.112  181.99  195.42  196.72  195.67  195.74  49.875
#
#         j       k       Y
# 0  11.782  173.23  16.509
# 1  11.645  171.45  16.343
# 2  11.751  170.77  16.433
# 3  11.728  171.16  16.433
# 4  11.684  193.45  16.455

# %% [markdown]
# ## Now finiding the best features using featurewiz

# %%
from featurewiz import featurewiz

# %%
target = 'Y'

# %%
feats = featurewiz(df, target, corr_limit=0.6, verbose=0)
len(feats)
# Out:
# Skipping feature engineering since no feature_engg input...
# Skipping category encoding since no category encoders specified in input...
# Shape of your Data Set loaded: (3491, 12)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     11 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# Shape of your Data Set loaded: (3491, 12)
#     No GPU active on this device
#     Running XGBoost using CPU parameters
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     11 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# #### Single_Label Regression Feature Selection Started ####
# Searching for highly correlated variables from 11 variables using SULOV method
# ...

# %%
#### Featurewiz returns the list of variables in the first part of it output
feats[0]
# Out:
# ['c', 'a', 'j', 'd', 'h']
